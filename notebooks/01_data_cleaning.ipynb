# %%
import sys
import os

# %%
#Add src to path
sys.path.append(os.path.abspath('../src'))

# %%
import importlib
import data_cleaning

importlib.reload(data_cleaning)

from data_cleaning import clean_pipeline

# %%
df = clean_pipeline("../data/raw/DataCoSupplyChainDataset.csv")

# %%
df.head(10)
# Out:
#        type  days_for_shipping_real  days_for_shipment_scheduled  \
# 0     DEBIT                       3                            4
# 1  TRANSFER                       5                            4
# 2      CASH                       4                            4
# 3     DEBIT                       3                            4
# 4   PAYMENT                       2                            4
# 5  TRANSFER                       6                            4
# 6     DEBIT                       2                            1
# 7  TRANSFER                       2                            1
# 8      CASH                       3                            2
# 9      CASH                       2                            1
#
#    sales_per_customer    delivery_status  late_delivery_risk   category_name  \
# 0           314.64001   Advance shipping                   0  Sporting Goods
# 1           311.35999      Late delivery                   1  Sporting Goods
# ...

# %%
df.shape
# Out:
# (180519, 25)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   type                         180519 non-null  str
#  1   days_for_shipping_real       180519 non-null  int64
#  2   days_for_shipment_scheduled  180519 non-null  int64
#  3   sales_per_customer           180519 non-null  float64
#  4   delivery_status              180519 non-null  str
#  5   late_delivery_risk           180519 non-null  int64
#  6   category_name                180519 non-null  str
#  7   customer_country             180519 non-null  str
#  8   customer_segment             180519 non-null  str
#  9   department_name              180519 non-null  str
#  10  order_date_dateorders        180519 non-null  str
#  11  order_id                     180519 non-null  int64
#  12  order_item_profit_ratio      180519 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# type                           0
# days_for_shipping_real         0
# days_for_shipment_scheduled    0
# sales_per_customer             0
# delivery_status                0
# late_delivery_risk             0
# category_name                  0
# customer_country               0
# customer_segment               0
# department_name                0
# order_date_dateorders          0
# order_id                       0
# order_item_profit_ratio        0
# sales                          0
# order_profit_per_order         0
# order_region                   0
# order_status                   0
# product_name                   0
# product_price                  0
# shipping_date_dateorders       0
# shipping_mode                  0
# order_date                     0
# shipping_date                  0
# order_processing_time          0
# delay                          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Saving Cleaned_Data CSV to Data Processed Folder

# %%
df.to_csv('../data/processed/cleaned_data.csv', index=False)
